# %% [markdown]
# ## Cargamos las Librerías Necesarias:

# %%
import empiricaldist
import matplotlib.pyplot as plt
import janitor
import numpy as np
import pandas as pd
import scipy.stats
import seaborn as sns
import sklearn.metrics
import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels.stats as ss
import session_info
import warnings
warnings.filterwarnings('ignore')
import nbformat
from IPython.core.interactiveshell import InteractiveShell

# %% [markdown]
# ## Utilizamos el Comando Mágico para Importar los Conjuntos de Datos:

# %%
# %run ../notebooks/probabilidad/congresos.py
# Out:
# Index(['Año', 'Nombre_estado', 'Municipio', 'Cargo', 'ID_Municipio',
#        'Ayuntamiento', 'Partido', 'Nombre_candidato', 'Sexo', 'Coalición',
#        'Formula'],
#       dtype='object')
# Index(['Año', 'ID_estado', 'Nombre_estado', 'ID_municipio', 'Municipio',
#        'Partido', 'Votos', 'Votos_validos', 'Votos_candidato_sin_registro',
#        'Votos_nulos', 'Total_de_votos', 'Lista_nominal', 'Coalición'],
#       dtype='object')
# Index(['Año', 'ID_estado', 'Nombre_estado', 'ID_municipio', 'Municipio',
#        'Partido', 'Votos', 'Votos_validos', 'Votos_candidato_sin_registro',
#        'Votos_nulos', 'Total_de_votos', 'Lista_nominal', 'Coalición'],
#       dtype='object')
# Columnas en votos: ['Año', 'ID_estado', 'Nombre_estado', 'ID_municipio', 'Municipio', 'Partido', 'Votos', 'Votos_validos', 'Votos_candidato_sin_registro', 'Votos_nulos', 'Total_de_votos', 'Lista_nominal', 'Coalición']
# Index(['Año', 'ID_estado', 'Nombre_estado', 'ID_municipio', 'Municipio',
#        'Partido', 'Votos', 'Votos_validos', 'Votos_candidato_sin_registro',
#        'Votos_nulos', 'Total_de_votos', 'Lista_nominal', 'Coalición'],
#       dtype='object')
# Index(['Año', 'Nombre_estado', 'Municipio', 'Partido_ganador', 'Coalición',
#        'Votos', 'Votos_validos', 'Votos_candidato_sin_registro', 'Votos_nulos',
#        'Total_de_votos', 'Lista_nominal'],
#       dtype='object')
#     Año  ID_estado        Nombre_estado  ID_municipio Municipio    Partido  \
# 0  2015          3  BAJA CALIFORNIA SUR             1   COMONDU    PAN_PRS
# 1  2015          3  BAJA CALIFORNIA SUR             1   COMONDU   PRI_PVEM
# 2  2015          3  BAJA CALIFORNIA SUR             1   COMONDU  PRD_PT_MC
# 3  2015          3  BAJA CALIFORNIA SUR             1   COMONDU       NUAL
# 4  2015          3  BAJA CALIFORNIA SUR             1   COMONDU     MORENA
#
#    Votos  Votos_validos  Votos_candidato_sin_registro  Votos_nulos  \
# 0  12818          29183                            13          987
# 1  10037          29183                            13          987
# 2   4975          29183                            13          987
# 3    351          29183                            13          987
# 4    412          29183                            13          987
#
#    Total_de_votos  Lista_nominal Coalición
# 0           30170          48403        Sí
# 1           30170          48403        Sí
# 2           30170          48403        Sí
# 3           30170          48403        No
# 4           30170          48403        No
# Año                   int64
# Nombre_estado        object
# Municipio            object
# Cargo                object
# ID_Municipio        float64
# Ayuntamiento         object
# Partido              object
# Nombre_candidato     object
# Sexo                 object
# Coalición            object
# Formula              object
# dtype: object
# Año                              int64
# ID_estado                        int64
# Nombre_estado                   object
# ID_municipio                     int64
# Municipio                       object
# Partido                         object
# Votos                            int64
# Votos_validos                    int64
# Votos_candidato_sin_registro     int64
# Votos_nulos                      int64
# Total_de_votos                   int64
# Lista_nominal                    int64
# Coalición                       object
# dtype: object
# Formula
# Mayoría relativa               1240
# Representación Proporcional     802
# Name: count, dtype: int64
# Index(['Año', 'ID_estado', 'Nombre_estado', 'ID_municipio', 'Municipio',
#        'Partido', 'Votos', 'Votos_validos', 'Votos_candidato_sin_registro',
#        'Votos_nulos', 'Total_de_votos', 'Lista_nominal', 'Coalición'],
#       dtype='object')
# Index(['Año', 'Nombre_estado', 'Municipio', 'Partido_ganador', 'Coalición',
#        'Votos', 'Votos_validos', 'Votos_candidato_sin_registro', 'Votos_nulos',
#        'Total_de_votos', 'Lista_nominal'],
#       dtype='object')
# Formula
# Mayoría relativa               1240
# Representación Proporcional     802
# Name: count, dtype: int64
#         Año  ID_estado Municipio      Partido  Votos  Nuevo_Votos
# 0      2015          3   COMONDU      PAN_PRS  12818            0
# 1      2015          3   COMONDU     PRI_PVEM  10037            0
# 2      2015          3   COMONDU    PRD_PT_MC   4975            0
# 3      2015          3   COMONDU         NUAL    351          351
# 4      2015          3   COMONDU       MORENA    412          412
# ...     ...        ...       ...          ...    ...          ...
# 61513  2023          5  ZARAGOZA       MORENA    947          947
# 61514  2023          5  ZARAGOZA  PAN_PRI_PRD     27         2332
# 61515  2023          5  ZARAGOZA      PAN_PRI     33         2280
# 61516  2023          5  ZARAGOZA      PAN_PRD      2          323
# 61517  2023          5  ZARAGOZA     PVEM_UDC     16         1214
#
# [61518 rows x 6 columns]

# %% [markdown]
# ## Cargamos los Conjuntos de Datos:

# %%
union
# Out:
#        Año   Nombre_estado                  Municipio       Cargo  \
# 0     2018  AGUASCALIENTES            RINCON DE ROMOS  Diputación
# 1     2018  AGUASCALIENTES                   EL LLANO  Diputación
# 2     2018  AGUASCALIENTES        PABELLON DE ARTEAGA  Diputación
# 3     2018  AGUASCALIENTES  SAN FRANCISCO DE LOS ROMO  Diputación
# 4     2018  AGUASCALIENTES             AGUASCALIENTES  Diputación
# ...    ...             ...                        ...         ...
# 2037  2023        COAHUILA                        nan  Diputación
# 2038  2023        COAHUILA                        nan  Diputación
# 2039  2023        COAHUILA                        nan  Diputación
# 2040  2023        COAHUILA                        nan  Diputación
# 2041  2023        COAHUILA                        nan  Diputación
#
#       ID_Municipio Ayuntamiento       Partido  \
# 0              NaN          NaN    PAN_PRD_MC
# 1              NaN          NaN  PT_MORENA_ES
# 2              NaN          NaN    PAN_PRD_MC
# 3              NaN          NaN    PAN_PRD_MC
# 4              NaN          NaN    PAN_PRD_MC
# ...            ...          ...           ...
# 2037           NaN          NaN        MORENA
# 2038           NaN          NaN        MORENA
# 2039           NaN          NaN        MORENA
# 2040           NaN          NaN        MORENA
# 2041           NaN          NaN        MORENA
#
#                          Nombre_candidato    Sexo Coalición  ...  \
# 0        MONICA JANETH JIMENEZ RODRIGUEZ   Mujer        Sí  ...
# 1               JOSE MANUEL GONZALEZ MOTA  Hombre        Sí  ...
# 2                    JORGE SAUCEDO GAYTAN  Hombre        Sí  ...
# 3            KARINA IVETTE EUDAVE DELGADO   Mujer        Sí  ...
# 4                  SALVADOR PEREZ SANCHEZ  Hombre        Sí  ...
# ...                                   ...     ...       ...  ...
# 2037                 WENDY BALCAZAR PEREZ   Mujer        No  ...
# 2038      DELIA AURORA HERNÁNDEZ ALVARADO   Mujer        No  ...
# 2039              ROSAURA MONROY BECERRIL   Mujer        No  ...
# 2040               LUIS JAIME PONCE ORTIZ  Hombre        No  ...
# 2041  YUDITH ELIZABETH RODRIGUEZ MARTINEZ   Mujer        No  ...
#
#      Total_de_votos  Lista_nominal  Partido_ganador  Coalición_ganador  \
# 0           20371.0        37004.0              PAN                 No
# 1            8865.0        14826.0           MORENA                 No
# 2           19103.0        30679.0           MORENA                 No
# 3           17671.0        32309.0              PRI                 No
# 4          377172.0       636960.0              PAN                 No
# ...             ...            ...              ...                ...
# 2037            NaN            NaN              NaN                NaN
# 2038            NaN            NaN              NaN                NaN
# 2039            NaN            NaN              NaN                NaN
# 2040            NaN            NaN              NaN                NaN
# 2041            NaN            NaN              NaN                NaN
#
#       Votos_ganador  Votos_validos_ganador  \
# 0            5051.0                19391.0
# 1            2435.0                 8520.0
# 2            4776.0                18387.0
# 3            5974.0                17104.0
# 4          125035.0               362367.0
# ...             ...                    ...
# 2037            NaN                    NaN
# 2038            NaN                    NaN
# 2039            NaN                    NaN
# 2040            NaN                    NaN
# 2041            NaN                    NaN
#
#       Votos_candidato_sin_registro_ganador  Votos_nulos_ganador  \
# 0                                     14.0                966.0
# 1                                      5.0                340.0
# 2                                     12.0                704.0
# 3                                     15.0                552.0
# 4                                    541.0              14264.0
# ...                                    ...                  ...
# 2037                                   NaN                  NaN
# 2038                                   NaN                  NaN
# 2039                                   NaN                  NaN
# 2040                                   NaN                  NaN
# 2041                                   NaN                  NaN
#
#       Total_de_votos_ganador Lista_nominal_ganador
# 0                    20371.0               37004.0
# 1                     8865.0               14826.0
# 2                    19103.0               30679.0
# 3                    17671.0               32309.0
# 4                   377172.0              636960.0
# ...                      ...                   ...
# 2037                     NaN                   NaN
# 2038                     NaN                   NaN
# 2039                     NaN                   NaN
# 2040                     NaN                   NaN
# 2041                     NaN                   NaN
#
# [2042 rows x 27 columns]

# %%
union_1
# Out:
#        Año   Nombre_estado                  Municipio       Cargo  \
# 0     2018  AGUASCALIENTES            RINCON DE ROMOS  Diputación
# 1     2018  AGUASCALIENTES                   EL LLANO  Diputación
# 2     2018  AGUASCALIENTES        PABELLON DE ARTEAGA  Diputación
# 3     2018  AGUASCALIENTES  SAN FRANCISCO DE LOS ROMO  Diputación
# 4     2018  AGUASCALIENTES             AGUASCALIENTES  Diputación
# ...    ...             ...                        ...         ...
# 2037  2023        COAHUILA                        nan  Diputación
# 2038  2023        COAHUILA                        nan  Diputación
# 2039  2023        COAHUILA                        nan  Diputación
# 2040  2023        COAHUILA                        nan  Diputación
# 2041  2023        COAHUILA                        nan  Diputación
#
#       ID_Municipio Ayuntamiento       Partido  \
# 0              NaN          NaN    PAN_PRD_MC
# 1              NaN          NaN  PT_MORENA_ES
# 2              NaN          NaN    PAN_PRD_MC
# 3              NaN          NaN    PAN_PRD_MC
# 4              NaN          NaN    PAN_PRD_MC
# ...            ...          ...           ...
# 2037           NaN          NaN        MORENA
# 2038           NaN          NaN        MORENA
# 2039           NaN          NaN        MORENA
# 2040           NaN          NaN        MORENA
# 2041           NaN          NaN        MORENA
#
#                          Nombre_candidato    Sexo Coalición  ...  \
# 0        MONICA JANETH JIMENEZ RODRIGUEZ   Mujer        Sí  ...
# 1               JOSE MANUEL GONZALEZ MOTA  Hombre        Sí  ...
# 2                    JORGE SAUCEDO GAYTAN  Hombre        Sí  ...
# 3            KARINA IVETTE EUDAVE DELGADO   Mujer        Sí  ...
# 4                  SALVADOR PEREZ SANCHEZ  Hombre        Sí  ...
# ...                                   ...     ...       ...  ...
# 2037                 WENDY BALCAZAR PEREZ   Mujer        No  ...
# 2038      DELIA AURORA HERNÁNDEZ ALVARADO   Mujer        No  ...
# 2039              ROSAURA MONROY BECERRIL   Mujer        No  ...
# 2040               LUIS JAIME PONCE ORTIZ  Hombre        No  ...
# 2041  YUDITH ELIZABETH RODRIGUEZ MARTINEZ   Mujer        No  ...
#
#      Total_de_votos  Lista_nominal  Partido_ganador  Coalición_ganador  \
# 0           20371.0        37004.0       PAN_PRD_MC                 Sí
# 1            8865.0        14826.0     PT_MORENA_ES                 Sí
# 2           19103.0        30679.0       PAN_PRD_MC                 Sí
# 3           17671.0        32309.0              PRI                 No
# 4          377172.0       636960.0       PAN_PRD_MC                 Sí
# ...             ...            ...              ...                ...
# 2037            NaN            NaN              NaN                NaN
# 2038            NaN            NaN              NaN                NaN
# 2039            NaN            NaN              NaN                NaN
# 2040            NaN            NaN              NaN                NaN
# 2041            NaN            NaN              NaN                NaN
#
#       Votos_ganador  Votos_validos_ganador  \
# 0            6171.0                19391.0
# 1            3198.0                 8520.0
# 2            6896.0                18387.0
# 3            5974.0                17104.0
# 4          141119.0               362367.0
# ...             ...                    ...
# 2037            NaN                    NaN
# 2038            NaN                    NaN
# 2039            NaN                    NaN
# 2040            NaN                    NaN
# 2041            NaN                    NaN
#
#       Votos_candidato_sin_registro_ganador  Votos_nulos_ganador  \
# 0                                     14.0                966.0
# 1                                      5.0                340.0
# 2                                     12.0                704.0
# 3                                     15.0                552.0
# 4                                    541.0              14264.0
# ...                                    ...                  ...
# 2037                                   NaN                  NaN
# 2038                                   NaN                  NaN
# 2039                                   NaN                  NaN
# 2040                                   NaN                  NaN
# 2041                                   NaN                  NaN
#
#       Total_de_votos_ganador Lista_nominal_ganador
# 0                    20371.0               37004.0
# 1                     8865.0               14826.0
# 2                    19103.0               30679.0
# 3                    17671.0               32309.0
# 4                   377172.0              636960.0
# ...                      ...                   ...
# 2037                     NaN                   NaN
# 2038                     NaN                   NaN
# 2039                     NaN                   NaN
# 2040                     NaN                   NaN
# 2041                     NaN                   NaN
#
# [2042 rows x 27 columns]

# %% [markdown]
# ## Primer Conjunto de Datos:

# %% [markdown]
# ### Estadística Descriptiva:

# %% [markdown]
# #### PMFs:

# %% [markdown]
# #### ECDFs:

# %% [markdown]
# #### PDFs:

# %% [markdown]
# ### Teoría del Límite Central:

# %% [markdown]
# ## Segundo Conjunto de Datos:

# %% [markdown]
# ### Estadística Descriptiva:

# %% [markdown]
# ### PMFs:

# %% [markdown]
# #### ECDFs:

# %% [markdown]
# #### PDFs:

# %% [markdown]
# ### Teoría del Límite Central:

# %% [markdown]
# ## Seccionamos los Conjuntos de Datos por Sexo:

# %% [markdown]
# ### Hombres:

# %% [markdown]
# #### Estadística Aplicada:

# %% [markdown]
# ##### PMFs:

# %% [markdown]
# ##### ECDFs:

# %% [markdown]
# ##### PDFs:

# %% [markdown]
# #### Teoría del Límite Central:

# %% [markdown]
# ### Mujeres:

# %% [markdown]
# #### Estadística Aplicada:

# %% [markdown]
# ##### PMFs:

# %% [markdown]
# ##### ECDFs:

# %% [markdown]
# ##### PDFs:

# %% [markdown]
# #### Teoría del Límite Central:
